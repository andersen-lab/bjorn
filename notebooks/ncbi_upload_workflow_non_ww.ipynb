# %%
# import statements
import sys
sys.path.append("../src")

from ncbi_upload import merge_metadata

# %%
# load the latest metadata and merge
repo_metadata_path = "/Users/karthikramesh/src/HCoV-19-Genomics/metadata.csv"
online_metadata_config = "../bjorn.ini"
online_metadata_old_path = "../data/ncbi_upload/COVID_sequencing_summary [March 2020 - March 2021] - GISAID.csv"
merged_combined_metadata = merge_metadata(repo_metadata_path, online_metadata_config, online_metadata_old_path)

# %%
# get metadata status

# %%
# load and convert the metadata for samples that are not from wastewater
non_wastewater_metadata = metadata_status[metadata_status["wastewater"] != "Yes"]
non_wastewater_converted_data = convert_metadata(non_wastewater_metadata,
                                                 "../data/ncbi_upload/metadata_column_mapping.json",
                                                 "../data/ncbi_upload/metadata_constant_mapping.json",
                                                 "../data/ncbi_upload/author_conversions.csv",
                                                False)
non_wastewater_converted_data
# Out:
# /Users/karthikramesh/src/bjorn/notebooks/../src/ncbi_upload.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   has_both_fields["collected_by"] = has_both_fields["collected_by_1"] + " with the help of " + has_both_fields["collected_by_2"]
# /Users/karthikramesh/src/bjorn/notebooks/../src/ncbi_upload.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   has_second_field["collected_by"] = has_second_field["collected_by_2"]
#            sample_name   alternative_ID collection_date  \
# 0               MG0987           MG0987         3/18/20
# 1             PC00101P         PC00101P         3/11/20
# 2      SEARCH-0007-SAN  SEARCH-0007-SAN         3/21/20
# 3      SEARCH-0016-SAN  SEARCH-0016-SAN         3/24/20
# 4      SEARCH-0017-SAN  SEARCH-0017-SAN         3/24/20
# ...                ...              ...             ...
# 24624     SEARCH-32788  CA-SEARCH-32788         5/13/21
# 24721     SEARCH-41159  CA-SEARCH-41159          7/7/21
# 24722     SEARCH-41164  CA-SEARCH-41164          7/6/21
# 24723     SEARCH-41165  CA-SEARCH-41165          7/6/21
# 24745     SEARCH-41204  CA-SEARCH-41204          7/1/21
#
#                    geo_loc_name  isolate isolation_source collection_method  \
# 0      USA:California:San Diego      NaN              NaN               NaN
# 1      USA:California:San Diego      NaN              NaN               NaN
# 2      USA:California:San Diego      NaN              NaN               NaN
# 3      USA:California:San Diego      NaN              NaN               NaN
# 4      USA:California:San Diego      NaN              NaN               NaN
# ...                         ...      ...              ...               ...
# 24624  USA:California:San Diego      NaN              NaN               NaN
# 24721  USA:California:San Diego      NaN              NaN               NaN
# 24722  USA:California:San Diego      NaN              NaN               NaN
# 24723  USA:California:San Diego      NaN              NaN               NaN
# 24745  USA:California:San Diego      NaN              NaN               NaN
#
#       gisaid_accession                                  gisaid_virus_name  \
# 0       EPI_ISL_416457                                   Consensus_MG0987
# 1       EPI_ISL_414648          Consensus_PC00101P_threshold_0_quality_20
# 2       EPI_ISL_429990  Consensus_SEARCH-0007-SAN_L1_threshold_0_quali...
# 3       EPI_ISL_430016  Consensus_SEARCH-0016-SAN_L1_threshold_0_quali...
# 4       EPI_ISL_429991  Consensus_SEARCH-0017-SAN_L1_threshold_0_quali...
# ...                ...                                                ...
# 24624  EPI_ISL_3215700                   hCoV-19/USA/CA-SEARCH-32788/2021
# 24721  EPI_ISL_3215798                   hCoV-19/USA/CA-SEARCH-41159/2021
# 24722  EPI_ISL_3215799                   hCoV-19/USA/CA-SEARCH-41164/2021
# 24723  EPI_ISL_3215800                   hCoV-19/USA/CA-SEARCH-41165/2021
# 24745  EPI_ISL_3215822                   hCoV-19/USA/CA-SEARCH-41204/2021
#
#       last_vaccinated_raw sequence_uploaded bam_uploaded wastewater  \
# 0                     NaN               Yes           No         No
# 1                     NaN               Yes          Yes         No
# 2                     NaN               Yes          Yes         No
# 3                     NaN               Yes          Yes         No
# 4                     NaN               Yes          Yes         No
# ...                   ...               ...          ...        ...
# 24624                 NaN                No           No         No
# 24721                 NaN                No           No         No
# 24722                 NaN                No           No         No
# 24723                 NaN                No           No         No
# 24745                 NaN                No           No         No
#
#       bioproject_accession    organism          host host_disease  \
# 0              PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# 1              PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# 2              PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# 3              PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# 4              PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# ...                    ...         ...           ...          ...
# 24624          PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# 24721          PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# 24722          PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# 24723          PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# 24745          PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
#
#                                             collected_by
# 0      SEARCH Alliance San Diego with the help of And...
# 1      SEARCH Alliance San Diego with the help of And...
# 2      SEARCH Alliance San Diego with Christina Clark...
# 3      SEARCH Alliance San Diego with the help of And...
# 4      SEARCH Alliance San Diego with the help of And...
# ...                                                  ...
# 24624                                         EXCITE Lab
# 24721                                         EXCITE Lab
# 24722                                         EXCITE Lab
# 24723                                         EXCITE Lab
# 24745                                         EXCITE Lab
#
# [30488 rows x 18 columns]

# %%
need_to_upload_non_ww = non_wastewater_converted_data[(~non_wastewater_converted_data["collected_by"].str.contains("Helix")) & (~non_wastewater_converted_data["gisaid_accession"].isna())]
need_to_upload_non_ww
# Out:
#            sample_name   alternative_ID collection_date  \
# 0               MG0987           MG0987         3/18/20
# 1             PC00101P         PC00101P         3/11/20
# 2      SEARCH-0007-SAN  SEARCH-0007-SAN         3/21/20
# 3      SEARCH-0016-SAN  SEARCH-0016-SAN         3/24/20
# 4      SEARCH-0017-SAN  SEARCH-0017-SAN         3/24/20
# ...                ...              ...             ...
# 24624     SEARCH-32788  CA-SEARCH-32788         5/13/21
# 24721     SEARCH-41159  CA-SEARCH-41159          7/7/21
# 24722     SEARCH-41164  CA-SEARCH-41164          7/6/21
# 24723     SEARCH-41165  CA-SEARCH-41165          7/6/21
# 24745     SEARCH-41204  CA-SEARCH-41204          7/1/21
#
#                    geo_loc_name  isolate isolation_source collection_method  \
# 0      USA:California:San Diego      NaN              NaN               NaN
# 1      USA:California:San Diego      NaN              NaN               NaN
# 2      USA:California:San Diego      NaN              NaN               NaN
# 3      USA:California:San Diego      NaN              NaN               NaN
# 4      USA:California:San Diego      NaN              NaN               NaN
# ...                         ...      ...              ...               ...
# 24624  USA:California:San Diego      NaN              NaN               NaN
# 24721  USA:California:San Diego      NaN              NaN               NaN
# 24722  USA:California:San Diego      NaN              NaN               NaN
# 24723  USA:California:San Diego      NaN              NaN               NaN
# 24745  USA:California:San Diego      NaN              NaN               NaN
#
#       gisaid_accession                                  gisaid_virus_name  \
# 0       EPI_ISL_416457                                   Consensus_MG0987
# 1       EPI_ISL_414648          Consensus_PC00101P_threshold_0_quality_20
# 2       EPI_ISL_429990  Consensus_SEARCH-0007-SAN_L1_threshold_0_quali...
# 3       EPI_ISL_430016  Consensus_SEARCH-0016-SAN_L1_threshold_0_quali...
# 4       EPI_ISL_429991  Consensus_SEARCH-0017-SAN_L1_threshold_0_quali...
# ...                ...                                                ...
# 24624  EPI_ISL_3215700                   hCoV-19/USA/CA-SEARCH-32788/2021
# 24721  EPI_ISL_3215798                   hCoV-19/USA/CA-SEARCH-41159/2021
# 24722  EPI_ISL_3215799                   hCoV-19/USA/CA-SEARCH-41164/2021
# 24723  EPI_ISL_3215800                   hCoV-19/USA/CA-SEARCH-41165/2021
# 24745  EPI_ISL_3215822                   hCoV-19/USA/CA-SEARCH-41204/2021
#
#       last_vaccinated_raw sequence_uploaded bam_uploaded wastewater  \
# 0                     NaN               Yes           No         No
# 1                     NaN               Yes          Yes         No
# 2                     NaN               Yes          Yes         No
# 3                     NaN               Yes          Yes         No
# 4                     NaN               Yes          Yes         No
# ...                   ...               ...          ...        ...
# 24624                 NaN                No           No         No
# 24721                 NaN                No           No         No
# 24722                 NaN                No           No         No
# 24723                 NaN                No           No         No
# 24745                 NaN                No           No         No
#
#       bioproject_accession    organism          host host_disease  \
# 0              PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# 1              PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# 2              PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# 3              PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# 4              PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# ...                    ...         ...           ...          ...
# 24624          PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# 24721          PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# 24722          PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# 24723          PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# 24745          PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
#
#                                             collected_by
# 0      SEARCH Alliance San Diego with the help of And...
# 1      SEARCH Alliance San Diego with the help of And...
# 2      SEARCH Alliance San Diego with Christina Clark...
# 3      SEARCH Alliance San Diego with the help of And...
# 4      SEARCH Alliance San Diego with the help of And...
# ...                                                  ...
# 24624                                         EXCITE Lab
# 24721                                         EXCITE Lab
# 24722                                         EXCITE Lab
# 24723                                         EXCITE Lab
# 24745                                         EXCITE Lab
#
# [20911 rows x 18 columns]

# %%
need_to_upload_non_ww = recover_vaccine_date(need_to_upload_non_ww).drop(columns=["last_vaccinated_raw", "date_of_sars_cov_2_vaccination"])
need_to_upload_non_ww
# Out:
# /Users/karthikramesh/src/bjorn/notebooks/../src/ncbi_upload.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   needs_to_be_vaccine_timestamped["date_of_sars_cov_2_vaccination"], needs_to_be_vaccine_timestamped["vaccine_received"] = _convert_str_date_to_timestamp(needs_to_be_vaccine_timestamped["last_vaccinated_raw"], needs_to_be_vaccine_timestamped["collection_date"])
# /Users/karthikramesh/src/bjorn/notebooks/../src/ncbi_upload.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   needs_to_be_vaccine_timestamped["date_of_sars_cov_2_vaccination"] = needs_to_be_vaccine_timestamped["date_of_sars_cov_2_vaccination"].dt.strftime('%Y-%m-%d')
#         sample_name collection_date              geo_loc_name  isolate  \
# 6105    SEARCH-8927         3/31/21  USA:California:San Diego      NaN
# 6106    SEARCH-8928         3/31/21  USA:California:San Diego      NaN
# 6107    SEARCH-8930         3/29/21  USA:California:San Diego      NaN
# 6108    SEARCH-8931         3/30/21  USA:California:San Diego      NaN
# 6306    SEARCH-9191          4/6/21  USA:California:San Diego      NaN
# ...             ...             ...                       ...      ...
# 19205  SEARCH-49984         8/11/21  USA:California:San Diego      NaN
# 19206  SEARCH-49989          8/3/21  USA:California:San Diego      NaN
# 19207  SEARCH-49991          8/4/21  USA:California:San Diego      NaN
# 19210  SEARCH-49996          8/9/21  USA:California:San Diego      NaN
# 19219  SEARCH-49988          8/3/21  USA:California:San Diego      NaN
#
#       isolation_source collection_method gisaid_accession  \
# 6105               NaN        Nasal swab  EPI_ISL_1794738
# 6106               NaN        Nasal swab  EPI_ISL_1794739
# 6107               NaN        Nasal swab  EPI_ISL_1794740
# 6108               NaN        Nasal swab  EPI_ISL_1794741
# 6306               NaN        Nasal swab  EPI_ISL_1794934
# ...                ...               ...              ...
# 19205              NaN               NaN  EPI_ISL_3908899
# 19206              NaN               NaN  EPI_ISL_3908901
# 19207              NaN               NaN  EPI_ISL_3908902
# 19210              NaN               NaN  EPI_ISL_3908906
# 19219              NaN               NaN  EPI_ISL_3908916
#
#                       gisaid_virus_name sequence_uploaded bam_uploaded  \
# 6105       hCoV-19/USA/SEARCH-8927/2021                No           No
# 6106       hCoV-19/USA/SEARCH-8928/2021                No           No
# 6107       hCoV-19/USA/SEARCH-8930/2021                No           No
# 6108       hCoV-19/USA/SEARCH-8931/2021                No           No
# 6306       hCoV-19/USA/SEARCH-9191/2021                No           No
# ...                                 ...               ...          ...
# 19205  hCoV-19/USA/CA-SEARCH-49984/2021               NaN          NaN
# 19206  hCoV-19/USA/CA-SEARCH-49989/2021               NaN          NaN
# 19207  hCoV-19/USA/CA-SEARCH-49991/2021               NaN          NaN
# 19210  hCoV-19/USA/CA-SEARCH-49996/2021               NaN          NaN
# 19219  hCoV-19/USA/CA-SEARCH-49988/2021               NaN          NaN
#
#       wastewater bioproject_accession    organism          host host_disease  \
# 6105          No          PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# 6106          No          PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# 6107          No          PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# 6108          No          PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# 6306          No          PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# ...          ...                  ...         ...           ...          ...
# 19205        NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# 19206        NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# 19207        NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# 19210        NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# 19219        NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
#
#                                             collected_by vaccine_received
# 6105   SEARCH Alliance San Diego with Michael Quigley...          vaccine
# 6106   SEARCH Alliance San Diego with Michael Quigley...           Pfizer
# 6107   SEARCH Alliance San Diego with Michael Quigley...           Pfizer
# 6108   SEARCH Alliance San Diego with Michael Quigley...           Pfizer
# 6306   SEARCH Alliance San Diego with Michael Quigley...          Moderna
# ...                                                  ...              ...
# 19205                                         EXCITE Lab              NaN
# 19206                                         EXCITE Lab              NaN
# 19207                                         EXCITE Lab              NaN
# 19210                                         EXCITE Lab              NaN
# 19219                                         EXCITE Lab              NaN
#
# [20968 rows x 17 columns]

# %%
# final cleanup
need_to_upload_non_ww[["collection_date", "geo_loc_name", "isolate", "isolation_source"]] = need_to_upload_non_ww[["collection_date", "geo_loc_name", "isolate", "isolation_source"]].fillna("not collected")
final_file = need_to_upload_non_ww.drop_duplicates(subset=["sample_name"]).fillna("")
final_file["collection_date"] = pd.to_datetime(final_file["collection_date"]).dt.strftime('%Y-%m-%d')
final_file["vaccine_received"].replace({"vaccine": "", "dose": ""}, inplace=True)
final_file
# Out:
#         sample_name collection_date              geo_loc_name        isolate  \
# 6105    SEARCH-8927      2021-03-31  USA:California:San Diego  not collected
# 6106    SEARCH-8928      2021-03-31  USA:California:San Diego  not collected
# 6107    SEARCH-8930      2021-03-29  USA:California:San Diego  not collected
# 6108    SEARCH-8931      2021-03-30  USA:California:San Diego  not collected
# 6306    SEARCH-9191      2021-04-06  USA:California:San Diego  not collected
# ...             ...             ...                       ...            ...
# 19205  SEARCH-49984      2021-08-11  USA:California:San Diego  not collected
# 19206  SEARCH-49989      2021-08-03  USA:California:San Diego  not collected
# 19207  SEARCH-49991      2021-08-04  USA:California:San Diego  not collected
# 19210  SEARCH-49996      2021-08-09  USA:California:San Diego  not collected
# 19219  SEARCH-49988      2021-08-03  USA:California:San Diego  not collected
#
#       isolation_source collection_method gisaid_accession  \
# 6105     not collected        Nasal swab  EPI_ISL_1794738
# 6106     not collected        Nasal swab  EPI_ISL_1794739
# 6107     not collected        Nasal swab  EPI_ISL_1794740
# 6108     not collected        Nasal swab  EPI_ISL_1794741
# 6306     not collected        Nasal swab  EPI_ISL_1794934
# ...                ...               ...              ...
# 19205    not collected                    EPI_ISL_3908899
# 19206    not collected                    EPI_ISL_3908901
# 19207    not collected                    EPI_ISL_3908902
# 19210    not collected                    EPI_ISL_3908906
# 19219    not collected                    EPI_ISL_3908916
#
#                       gisaid_virus_name sequence_uploaded bam_uploaded  \
# 6105       hCoV-19/USA/SEARCH-8927/2021                No           No
# 6106       hCoV-19/USA/SEARCH-8928/2021                No           No
# 6107       hCoV-19/USA/SEARCH-8930/2021                No           No
# 6108       hCoV-19/USA/SEARCH-8931/2021                No           No
# 6306       hCoV-19/USA/SEARCH-9191/2021                No           No
# ...                                 ...               ...          ...
# 19205  hCoV-19/USA/CA-SEARCH-49984/2021
# 19206  hCoV-19/USA/CA-SEARCH-49989/2021
# 19207  hCoV-19/USA/CA-SEARCH-49991/2021
# 19210  hCoV-19/USA/CA-SEARCH-49996/2021
# 19219  hCoV-19/USA/CA-SEARCH-49988/2021
#
#       wastewater bioproject_accession    organism          host host_disease  \
# 6105          No          PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# 6106          No          PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# 6107          No          PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# 6108          No          PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# 6306          No          PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# ...          ...                  ...         ...           ...          ...
# 19205                     PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# 19206                     PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# 19207                     PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# 19210                     PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
# 19219                     PRJNA612578  SARS-CoV-2  Homo Sapiens     COVID-19
#
#                                             collected_by vaccine_received
# 6105   SEARCH Alliance San Diego with Michael Quigley...
# 6106   SEARCH Alliance San Diego with Michael Quigley...           Pfizer
# 6107   SEARCH Alliance San Diego with Michael Quigley...           Pfizer
# 6108   SEARCH Alliance San Diego with Michael Quigley...           Pfizer
# 6306   SEARCH Alliance San Diego with Michael Quigley...          Moderna
# ...                                                  ...              ...
# 19205                                         EXCITE Lab
# 19206                                         EXCITE Lab
# 19207                                         EXCITE Lab
# 19210                                         EXCITE Lab
# 19219                                         EXCITE Lab
#
# [20959 rows x 17 columns]
