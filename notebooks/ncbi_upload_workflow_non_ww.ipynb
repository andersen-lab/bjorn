# %%
import glob
import os
import shutil
import sys
sys.path.append("../src")

from ncbi_upload import convert_metadata, merge_metadata, recover_vaccine_date, _convert_str_date_to_timestamp
import pandas as pd

# %%
def check_name(name, reference):
    if name in reference:
        return "Yes"
    else:
        return "No"

# %%
with open("../data/ncbi_upload/nuccore_result.txt", 'r') as infile:
    lines = infile.readlines()
    lines_blanked = [line if "Severe" in line else 1000 for line in lines]
    relevant_lines = list(filter((1000).__ne__, lines_blanked))

# %%
uploaded_sequences = [line.split(" ")[8].split("/")[3] for line in relevant_lines]

# %%
len(uploaded_sequences)
# Out:
# 1034

# %%
uploaded_bam_files = pd.read_csv("../data/ncbi_upload/sra_result.csv")["Library Name"].to_list()

# %%
len(uploaded_bam_files)
# Out:
# 965

# %%
with open("../data/ncbi_upload/wastewater_samples.txt", "r") as infile:
        lines = infile.readlines()
        wastewater_samples_list = [line.split("/")[1].split(".")[0] for line in lines]
len(wastewater_samples_list)
# Out:
# 215

# %%
all_files = glob.glob("/Users/karthikramesh/src/HCoV-19-Genomics/consensus_sequences/*.fasta")
all_names = [file.split("/")[6].split(".")[0] for file in all_files]
# build a dictionary from this
mapping_dict = {file: {"sequence_uploaded": check_name(file, uploaded_sequences),
                       "bam_uploaded": check_name(file, uploaded_bam_files),
                       "wastewater": check_name(file, wastewater_samples_list)} for file in all_names}

# %%
status_df = pd.DataFrame.from_dict(mapping_dict, orient='index')
status_df
# Out:
#                   sequence_uploaded bam_uploaded wastewater
# STM-0000072-E03                  No           No         No
# STM-0000104-B04                  No           No         No
# SEARCH-5347-SAN                  No           No         No
# SEARCH-102584                    No           No         No
# BCN-SEARCH-102962                No           No         No
# ...                             ...          ...        ...
# IS-SEARCH-108029                 No           No         No
# STM-0000038-A09                  No           No         No
# CA-SEARCH-46481                  No           No         No
# SEARCH-14138                     No           No         No
# STM-0000143-B04                  No           No         No
#
# [28523 rows x 3 columns]

# %%
# load and merge metadata
online_metadata = pd.read_csv("../data/ncbi_upload/metadata_online.csv")
repo_metadata = pd.read_csv("../data/ncbi_upload/metadata.csv")
metadata = merge_metadata(repo_metadata, online_metadata)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/bioenv/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
metadata
# Out:
#                     ID gb_accession gisaid_accession collection_date  \
# 0               MG0987     MT598172   EPI_ISL_416457         3/18/20
# 1             PC00101P     MT192765   EPI_ISL_414648         3/11/20
# 2      SEARCH-0007-SAN     MT598171   EPI_ISL_429990         3/21/20
# 3      SEARCH-0016-SAN     MT598173   EPI_ISL_430016         3/24/20
# 4      SEARCH-0017-SAN     MT598174   EPI_ISL_429991         3/24/20
# ...                ...          ...              ...             ...
# 30698    SEARCH-108990          NaN  EPI_ISL_4412901         8/16/21
# 30699    SEARCH-108991          NaN  EPI_ISL_4412904         8/17/21
# 30700    SEARCH-108993          NaN  EPI_ISL_4412907         8/30/21
# 30701    SEARCH-108996          NaN  EPI_ISL_4412909         8/16/21
# 30702    SEARCH-108997          NaN  EPI_ISL_4412910         8/16/21
#
#                        location  percent_coverage_cds  avg_depth  \
# 0      USA/California/San Diego               99.5954    2465.60
# 1      USA/California/San Diego               99.7525    3516.14
# 2      USA/California/San Diego              100.0000    6215.17
# 3      USA/California/San Diego              100.0000    6440.67
# 4      USA/California/San Diego              100.0000    4947.09
# ...                         ...                   ...        ...
# 30698  USA/California/San Diego               99.9796        NaN
# 30699  USA/California/San Diego               99.8062        NaN
# 30700  USA/California/San Diego               99.8912        NaN
# 30701  USA/California/San Diego               99.8232        NaN
# 30702  USA/California/San Diego               99.9660        NaN
#
#                                                  authors  \
# 0                              SEARCH Alliance San Diego
# 1                              SEARCH Alliance San Diego
# 2      SEARCH Alliance San Diego with Christina Clark...
# 3                              SEARCH Alliance San Diego
# 4                              SEARCH Alliance San Diego
# ...                                                  ...
# 30698  SEARCH Alliance San Diego with Ashleigh Murphy...
# 30699  SEARCH Alliance San Diego with Ashleigh Murphy...
# 30700  SEARCH Alliance San Diego with Ashleigh Murphy...
# 30701  SEARCH Alliance San Diego with Ashleigh Murphy...
# 30702  SEARCH Alliance San Diego with Ashleigh Murphy...
#
#                                  originating_lab  \
# 0               Andersen lab at Scripps Research
# 1               Andersen lab at Scripps Research
# 2                       Rady Children’s Hospital
# 3               Andersen lab at Scripps Research
# 4               Andersen lab at Scripps Research
# ...                                          ...
# 30698  San Diego County Public Health Laboratory
# 30699  San Diego County Public Health Laboratory
# 30700  San Diego County Public Health Laboratory
# 30701  San Diego County Public Health Laboratory
# 30702  San Diego County Public Health Laboratory
#
#                                                fasta_hdr  ...  \
# 0                                       Consensus_MG0987  ...
# 1              Consensus_PC00101P_threshold_0_quality_20  ...
# 2      Consensus_SEARCH-0007-SAN_L1_threshold_0_quali...  ...
# 3      Consensus_SEARCH-0016-SAN_L1_threshold_0_quali...  ...
# 4      Consensus_SEARCH-0017-SAN_L1_threshold_0_quali...  ...
# ...                                                  ...  ...
# 30698                  hCoV-19/USA/CA-SEARCH-108990/2021  ...
# 30699                  hCoV-19/USA/CA-SEARCH-108991/2021  ...
# 30700                  hCoV-19/USA/CA-SEARCH-108993/2021  ...
# 30701                  hCoV-19/USA/CA-SEARCH-108996/2021  ...
# 30702                  hCoV-19/USA/CA-SEARCH-108997/2021  ...
#
#       Sequencing technology Assembly method Coverage  \
# 0                       NaN             NaN      NaN
# 1                       NaN             NaN      NaN
# 2                       NaN             NaN      NaN
# 3                       NaN             NaN      NaN
# 4                       NaN             NaN      NaN
# ...                     ...             ...      ...
# 30698              Illumina      iVar 1.3.1    100.0
# 30699              Illumina      iVar 1.3.1     99.8
# 30700              Illumina      iVar 1.3.1     99.9
# 30701              Illumina      iVar 1.3.1     99.8
# 30702              Illumina      iVar 1.3.1    100.0
#
#                                  Originating lab  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 30698  San Diego County Public Health Laboratory
# 30699  San Diego County Public Health Laboratory
# 30700  San Diego County Public Health Laboratory
# 30701  San Diego County Public Health Laboratory
# 30702  San Diego County Public Health Laboratory
#
#                                         Address  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 30698  3851 Rosecrans St., San Diego, CA, 92110
# 30699  3851 Rosecrans St., San Diego, CA, 92110
# 30700  3851 Rosecrans St., San Diego, CA, 92110
# 30701  3851 Rosecrans St., San Diego, CA, 92110
# 30702  3851 Rosecrans St., San Diego, CA, 92110
#
#       Sample ID given by the sample provider  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 30698                          SEARCH-108990
# 30699                          SEARCH-108991
# 30700                          SEARCH-108993
# 30701                          SEARCH-108996
# 30702                          SEARCH-108997
#
#                          Submitting lab  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 30698  Andersen lab at Scripps Research
# 30699  Andersen lab at Scripps Research
# 30700  Andersen lab at Scripps Research
# 30701  Andersen lab at Scripps Research
# 30702  Andersen lab at Scripps Research
#
#                                                Address.1  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 30698  10550 North Torrey Pines Road, La Jolla, CA 92037
# 30699  10550 North Torrey Pines Road, La Jolla, CA 92037
# 30700  10550 North Torrey Pines Road, La Jolla, CA 92037
# 30701  10550 North Torrey Pines Road, La Jolla, CA 92037
# 30702  10550 North Torrey Pines Road, La Jolla, CA 92037
#
#       Sample ID given by the submitting laboratory  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 30698                                SEARCH-108990
# 30699                                SEARCH-108991
# 30700                                SEARCH-108993
# 30701                                SEARCH-108996
# 30702                                SEARCH-108997
#
#                                                  Authors
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 30698  SEARCH Alliance San Diego with Ashleigh Murphy...
# 30699  SEARCH Alliance San Diego with Ashleigh Murphy...
# 30700  SEARCH Alliance San Diego with Ashleigh Murphy...
# 30701  SEARCH Alliance San Diego with Ashleigh Murphy...
# 30702  SEARCH Alliance San Diego with Ashleigh Murphy...
#
# [30703 rows x 43 columns]

# %%
metadata_asia = metadata[metadata["location"].str.contains("Pakistan|Jordan", na=False)]
metadata_na = metadata[~metadata["location"].str.contains("Pakistan|Jordan", na=False)]
metadata_asia["location"] = "Asia" + "/" + metadata_asia["location"]
metadata_na["location"] = "North America" + "/" + metadata_na["location"]
metadata = pd.concat([metadata_na, metadata_asia])
metadata
# Out:
# /var/folders/bm/jvvhm5p54550nqrm3fz3bry40000gn/T/ipykernel_25145/2308663862.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata_asia["location"] = "Asia" + "/" + metadata_asia["location"]
# /var/folders/bm/jvvhm5p54550nqrm3fz3bry40000gn/T/ipykernel_25145/2308663862.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata_na["location"] = "North America" + "/" + metadata_na["location"]
#                     ID gb_accession gisaid_accession collection_date  \
# 0               MG0987     MT598172   EPI_ISL_416457         3/18/20
# 1             PC00101P     MT192765   EPI_ISL_414648         3/11/20
# 2      SEARCH-0007-SAN     MT598171   EPI_ISL_429990         3/21/20
# 3      SEARCH-0016-SAN     MT598173   EPI_ISL_430016         3/24/20
# 4      SEARCH-0017-SAN     MT598174   EPI_ISL_429991         3/24/20
# ...                ...          ...              ...             ...
# 30135    SEARCH-108236          NaN  EPI_ISL_4269128         3/15/21
# 30136    SEARCH-108239          NaN  EPI_ISL_4269129         5/10/21
# 30137    SEARCH-108241          NaN  EPI_ISL_4269130         5/17/21
# 30138    SEARCH-108243          NaN  EPI_ISL_4269131          5/8/21
# 30139    SEARCH-108244          NaN  EPI_ISL_4269132         5/16/21
#
#                                      location  percent_coverage_cds  \
# 0      North America/USA/California/San Diego               99.5954
# 1      North America/USA/California/San Diego               99.7525
# 2      North America/USA/California/San Diego              100.0000
# 3      North America/USA/California/San Diego              100.0000
# 4      North America/USA/California/San Diego              100.0000
# ...                                       ...                   ...
# 30135             Asia/Pakistan/Punjab/Lahore               99.9320
# 30136             Asia/Pakistan/Punjab/Lahore              100.0000
# 30137             Asia/Pakistan/Punjab/Lahore              100.0000
# 30138             Asia/Pakistan/Punjab/Lahore              100.0000
# 30139             Asia/Pakistan/Punjab/Lahore              100.0000
#
#        avg_depth                                            authors  \
# 0        2465.60                          SEARCH Alliance San Diego
# 1        3516.14                          SEARCH Alliance San Diego
# 2        6215.17  SEARCH Alliance San Diego with Christina Clark...
# 3        6440.67                          SEARCH Alliance San Diego
# 4        4947.09                          SEARCH Alliance San Diego
# ...          ...                                                ...
# 30135        NaN  SEARCH Alliance with Shifa Tameer-e-Millat Uni...
# 30136        NaN  SEARCH Alliance with Shifa Tameer-e-Millat Uni...
# 30137        NaN  SEARCH Alliance with Shifa Tameer-e-Millat Uni...
# 30138        NaN  SEARCH Alliance with Shifa Tameer-e-Millat Uni...
# 30139        NaN  SEARCH Alliance with Shifa Tameer-e-Millat Uni...
#
#                         originating_lab  \
# 0      Andersen lab at Scripps Research
# 1      Andersen lab at Scripps Research
# 2              Rady Children’s Hospital
# 3      Andersen lab at Scripps Research
# 4      Andersen lab at Scripps Research
# ...                                 ...
# 30135       Islamabad Diagnostic Center
# 30136       Islamabad Diagnostic Center
# 30137       Islamabad Diagnostic Center
# 30138       Islamabad Diagnostic Center
# 30139       Islamabad Diagnostic Center
#
#                                                fasta_hdr  ...  \
# 0                                       Consensus_MG0987  ...
# 1              Consensus_PC00101P_threshold_0_quality_20  ...
# 2      Consensus_SEARCH-0007-SAN_L1_threshold_0_quali...  ...
# 3      Consensus_SEARCH-0016-SAN_L1_threshold_0_quali...  ...
# 4      Consensus_SEARCH-0017-SAN_L1_threshold_0_quali...  ...
# ...                                                  ...  ...
# 30135             hCoV-19/Pakistan/PB-SEARCH-108236/2021  ...
# 30136             hCoV-19/Pakistan/PB-SEARCH-108239/2021  ...
# 30137             hCoV-19/Pakistan/PB-SEARCH-108241/2021  ...
# 30138             hCoV-19/Pakistan/PB-SEARCH-108243/2021  ...
# 30139             hCoV-19/Pakistan/PB-SEARCH-108244/2021  ...
#
#       Sequencing technology Assembly method Coverage  \
# 0                       NaN             NaN      NaN
# 1                       NaN             NaN      NaN
# 2                       NaN             NaN      NaN
# 3                       NaN             NaN      NaN
# 4                       NaN             NaN      NaN
# ...                     ...             ...      ...
# 30135              Illumina      iVar 1.3.1     99.9
# 30136              Illumina      iVar 1.3.1    100.0
# 30137              Illumina      iVar 1.3.1    100.0
# 30138              Illumina      iVar 1.3.1    100.0
# 30139              Illumina      iVar 1.3.1    100.0
#
#                    Originating lab                                    Address  \
# 0                              NaN                                        NaN
# 1                              NaN                                        NaN
# 2                              NaN                                        NaN
# 3                              NaN                                        NaN
# 4                              NaN                                        NaN
# ...                            ...                                        ...
# 30135  Islamabad Diagnostic Center  13-A Kohistan Rd., F-8 Markaz, Islamabad
# 30136  Islamabad Diagnostic Center  13-A Kohistan Rd., F-8 Markaz, Islamabad
# 30137  Islamabad Diagnostic Center  13-A Kohistan Rd., F-8 Markaz, Islamabad
# 30138  Islamabad Diagnostic Center  13-A Kohistan Rd., F-8 Markaz, Islamabad
# 30139  Islamabad Diagnostic Center  13-A Kohistan Rd., F-8 Markaz, Islamabad
#
#       Sample ID given by the sample provider  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 30135                          SEARCH-108236
# 30136                          SEARCH-108239
# 30137                          SEARCH-108241
# 30138                          SEARCH-108243
# 30139                          SEARCH-108244
#
#                          Submitting lab  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 30135  Andersen lab at Scripps Research
# 30136  Andersen lab at Scripps Research
# 30137  Andersen lab at Scripps Research
# 30138  Andersen lab at Scripps Research
# 30139  Andersen lab at Scripps Research
#
#                                                Address.1  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 30135  10550 North Torrey Pines Road, La Jolla, CA 92037
# 30136  10550 North Torrey Pines Road, La Jolla, CA 92037
# 30137  10550 North Torrey Pines Road, La Jolla, CA 92037
# 30138  10550 North Torrey Pines Road, La Jolla, CA 92037
# 30139  10550 North Torrey Pines Road, La Jolla, CA 92037
#
#       Sample ID given by the submitting laboratory  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 30135                                SEARCH-108236
# 30136                                SEARCH-108239
# 30137                                SEARCH-108241
# 30138                                SEARCH-108243
# 30139                                SEARCH-108244
#
#                                                  Authors
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 30135  SEARCH Alliance with Shifa Tameer-e-Millat Uni...
# 30136  SEARCH Alliance with Shifa Tameer-e-Millat Uni...
# 30137  SEARCH Alliance with Shifa Tameer-e-Millat Uni...
# 30138  SEARCH Alliance with Shifa Tameer-e-Millat Uni...
# 30139  SEARCH Alliance with Shifa Tameer-e-Millat Uni...
#
# [30703 rows x 43 columns]

# %%
# load and convert the metadata for samples that are not from wastewater
uploaded_or_wastewater = list(status_df[(status_df["wastewater"] == "Yes") | (status_df["sequence_uploaded"] == "Yes")].index)
non_wastewater_metadata = metadata[~metadata["ID"].isin(uploaded_or_wastewater)]
non_wastewater_converted_data = convert_metadata(non_wastewater_metadata,
                                                 "../data/ncbi_upload/metadata_column_mapping.json",
                                                 "../data/ncbi_upload/metadata_constant_mapping.json",
                                                 "../data/ncbi_upload/author_conversions.csv",
                                                False)
non_wastewater_converted_data
# Out:
# /Users/karthikramesh/src/bjorn/notebooks/../src/ncbi_upload.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   has_both_fields["collected_by"] = has_both_fields["collected_by_1"] + " with the help of " + has_both_fields["collected_by_2"]
# /Users/karthikramesh/src/bjorn/notebooks/../src/ncbi_upload.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   has_second_field["collected_by"] = has_second_field["collected_by_2"]
#            sample_name collection_date  \
# 0      SEARCH-0063-NBG         3/31/20
# 1      SEARCH-0096-SAN         3/19/20
# 2      SEARCH-0106-SAN         3/14/20
# 3      SEARCH-0107-SAN         3/13/20
# 4      SEARCH-0114-SAN         3/19/20
# ...                ...             ...
# 17600     SEARCH-49984         8/11/21
# 17601     SEARCH-49989          8/3/21
# 17602     SEARCH-49991          8/4/21
# 17605     SEARCH-49996          8/9/21
# 17614     SEARCH-49988          8/3/21
#
#                                   geo_loc_name  isolate isolation_source  \
# 0      North America:USA:Louisiana:New Orleans      NaN              NaN
# 1       North America:USA:California:San Diego      NaN              NaN
# 2       North America:USA:California:San Diego      NaN              NaN
# 3       North America:USA:California:San Diego      NaN              NaN
# 4       North America:USA:California:San Diego      NaN              NaN
# ...                                        ...      ...              ...
# 17600   North America:USA:California:San Diego      NaN              NaN
# 17601   North America:USA:California:San Diego      NaN              NaN
# 17602   North America:USA:California:San Diego      NaN              NaN
# 17605   North America:USA:California:San Diego      NaN              NaN
# 17614   North America:USA:California:San Diego      NaN              NaN
#
#          collection_method gisaid_accession                 gisaid_virus_name  \
# 0      Nasopharyngeal swab   EPI_ISL_434520  hCoV-19/USA/SEARCH-0063-NBG/2020
# 1      Nasopharyngeal swab              NaN  hCoV-19/USA/SEARCH-0096-SAN/2020
# 2      Nasopharyngeal swab   EPI_ISL_445102  hCoV-19/USA/SEARCH-0106-SAN/2020
# 3      Nasopharyngeal swab   EPI_ISL_445103  hCoV-19/USA/SEARCH-0107-SAN/2020
# 4      Nasopharyngeal swab              NaN  hCoV-19/USA/SEARCH-0114-SAN/2020
# ...                    ...              ...                               ...
# 17600                  NaN  EPI_ISL_3908899  hCoV-19/USA/CA-SEARCH-49984/2021
# 17601                  NaN  EPI_ISL_3908901  hCoV-19/USA/CA-SEARCH-49989/2021
# 17602                  NaN  EPI_ISL_3908902  hCoV-19/USA/CA-SEARCH-49991/2021
# 17605                  NaN  EPI_ISL_3908906  hCoV-19/USA/CA-SEARCH-49996/2021
# 17614                  NaN  EPI_ISL_3908916  hCoV-19/USA/CA-SEARCH-49988/2021
#
#       last_vaccinated_raw bioproject_accession    organism          host  \
# 0                     NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens
# 1                     NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens
# 2                     NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens
# 3                     NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens
# 4                     NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens
# ...                   ...                  ...         ...           ...
# 17600                 NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens
# 17601                 NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens
# 17602                 NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens
# 17605                 NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens
# 17614                 NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens
#
#       host_disease                                       collected_by
# 0         COVID-19  Allison Smither, Gilberto Sabino-Santos, Patri...
# 1         COVID-19  SEARCH Alliance San Diego with David Pride, Ji...
# 2         COVID-19  SEARCH Alliance San Diego with David Pride, Ji...
# 3         COVID-19  SEARCH Alliance San Diego with David Pride, Ji...
# 4         COVID-19  SEARCH Alliance San Diego with David Pride, Ji...
# ...            ...                                                ...
# 17600     COVID-19                                         EXCITE Lab
# 17601     COVID-19                                         EXCITE Lab
# 17602     COVID-19                                         EXCITE Lab
# 17605     COVID-19                                         EXCITE Lab
# 17614     COVID-19                                         EXCITE Lab
#
# [29508 rows x 14 columns]

# %%
non_wastewater_converted_data[(~non_wastewater_converted_data["collected_by"].str.contains("Helix"))]
# Out:
#            sample_name collection_date  \
# 0      SEARCH-0063-NBG         3/31/20
# 1      SEARCH-0096-SAN         3/19/20
# 2      SEARCH-0106-SAN         3/14/20
# 3      SEARCH-0107-SAN         3/13/20
# 4      SEARCH-0114-SAN         3/19/20
# ...                ...             ...
# 17600     SEARCH-49984         8/11/21
# 17601     SEARCH-49989          8/3/21
# 17602     SEARCH-49991          8/4/21
# 17605     SEARCH-49996          8/9/21
# 17614     SEARCH-49988          8/3/21
#
#                                   geo_loc_name  isolate isolation_source  \
# 0      North America:USA:Louisiana:New Orleans      NaN              NaN
# 1       North America:USA:California:San Diego      NaN              NaN
# 2       North America:USA:California:San Diego      NaN              NaN
# 3       North America:USA:California:San Diego      NaN              NaN
# 4       North America:USA:California:San Diego      NaN              NaN
# ...                                        ...      ...              ...
# 17600   North America:USA:California:San Diego      NaN              NaN
# 17601   North America:USA:California:San Diego      NaN              NaN
# 17602   North America:USA:California:San Diego      NaN              NaN
# 17605   North America:USA:California:San Diego      NaN              NaN
# 17614   North America:USA:California:San Diego      NaN              NaN
#
#          collection_method gisaid_accession                 gisaid_virus_name  \
# 0      Nasopharyngeal swab   EPI_ISL_434520  hCoV-19/USA/SEARCH-0063-NBG/2020
# 1      Nasopharyngeal swab              NaN  hCoV-19/USA/SEARCH-0096-SAN/2020
# 2      Nasopharyngeal swab   EPI_ISL_445102  hCoV-19/USA/SEARCH-0106-SAN/2020
# 3      Nasopharyngeal swab   EPI_ISL_445103  hCoV-19/USA/SEARCH-0107-SAN/2020
# 4      Nasopharyngeal swab              NaN  hCoV-19/USA/SEARCH-0114-SAN/2020
# ...                    ...              ...                               ...
# 17600                  NaN  EPI_ISL_3908899  hCoV-19/USA/CA-SEARCH-49984/2021
# 17601                  NaN  EPI_ISL_3908901  hCoV-19/USA/CA-SEARCH-49989/2021
# 17602                  NaN  EPI_ISL_3908902  hCoV-19/USA/CA-SEARCH-49991/2021
# 17605                  NaN  EPI_ISL_3908906  hCoV-19/USA/CA-SEARCH-49996/2021
# 17614                  NaN  EPI_ISL_3908916  hCoV-19/USA/CA-SEARCH-49988/2021
#
#       last_vaccinated_raw bioproject_accession    organism          host  \
# 0                     NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens
# 1                     NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens
# 2                     NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens
# 3                     NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens
# 4                     NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens
# ...                   ...                  ...         ...           ...
# 17600                 NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens
# 17601                 NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens
# 17602                 NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens
# 17605                 NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens
# 17614                 NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens
#
#       host_disease                                       collected_by
# 0         COVID-19  Allison Smither, Gilberto Sabino-Santos, Patri...
# 1         COVID-19  SEARCH Alliance San Diego with David Pride, Ji...
# 2         COVID-19  SEARCH Alliance San Diego with David Pride, Ji...
# 3         COVID-19  SEARCH Alliance San Diego with David Pride, Ji...
# 4         COVID-19  SEARCH Alliance San Diego with David Pride, Ji...
# ...            ...                                                ...
# 17600     COVID-19                                         EXCITE Lab
# 17601     COVID-19                                         EXCITE Lab
# 17602     COVID-19                                         EXCITE Lab
# 17605     COVID-19                                         EXCITE Lab
# 17614     COVID-19                                         EXCITE Lab
#
# [20391 rows x 14 columns]

# %%
need_to_upload_non_ww = non_wastewater_converted_data[(~non_wastewater_converted_data["collected_by"].str.contains("Helix")) & (~non_wastewater_converted_data["gisaid_accession"].isna())]
need_to_upload_non_ww
# Out:
#            sample_name collection_date  \
# 0      SEARCH-0063-NBG         3/31/20
# 2      SEARCH-0106-SAN         3/14/20
# 3      SEARCH-0107-SAN         3/13/20
# 9      SEARCH-0215-NBG          4/3/20
# 10     SEARCH-0244-SAN         3/28/20
# ...                ...             ...
# 17600     SEARCH-49984         8/11/21
# 17601     SEARCH-49989          8/3/21
# 17602     SEARCH-49991          8/4/21
# 17605     SEARCH-49996          8/9/21
# 17614     SEARCH-49988          8/3/21
#
#                                   geo_loc_name  isolate isolation_source  \
# 0      North America:USA:Louisiana:New Orleans      NaN              NaN
# 2       North America:USA:California:San Diego      NaN              NaN
# 3       North America:USA:California:San Diego      NaN              NaN
# 9      North America:USA:Louisiana:New Orleans      NaN              NaN
# 10      North America:USA:California:San Diego      NaN              NaN
# ...                                        ...      ...              ...
# 17600   North America:USA:California:San Diego      NaN              NaN
# 17601   North America:USA:California:San Diego      NaN              NaN
# 17602   North America:USA:California:San Diego      NaN              NaN
# 17605   North America:USA:California:San Diego      NaN              NaN
# 17614   North America:USA:California:San Diego      NaN              NaN
#
#          collection_method gisaid_accession                 gisaid_virus_name  \
# 0      Nasopharyngeal swab   EPI_ISL_434520  hCoV-19/USA/SEARCH-0063-NBG/2020
# 2      Nasopharyngeal swab   EPI_ISL_445102  hCoV-19/USA/SEARCH-0106-SAN/2020
# 3      Nasopharyngeal swab   EPI_ISL_445103  hCoV-19/USA/SEARCH-0107-SAN/2020
# 9      Nasopharyngeal swab   EPI_ISL_437541  hCoV-19/USA/SEARCH-0215-NBG/2020
# 10     Nasopharyngeal swab   EPI_ISL_437565  hCoV-19/USA/SEARCH-0244-SAN/2020
# ...                    ...              ...                               ...
# 17600                  NaN  EPI_ISL_3908899  hCoV-19/USA/CA-SEARCH-49984/2021
# 17601                  NaN  EPI_ISL_3908901  hCoV-19/USA/CA-SEARCH-49989/2021
# 17602                  NaN  EPI_ISL_3908902  hCoV-19/USA/CA-SEARCH-49991/2021
# 17605                  NaN  EPI_ISL_3908906  hCoV-19/USA/CA-SEARCH-49996/2021
# 17614                  NaN  EPI_ISL_3908916  hCoV-19/USA/CA-SEARCH-49988/2021
#
#       last_vaccinated_raw bioproject_accession    organism          host  \
# 0                     NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens
# 2                     NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens
# 3                     NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens
# 9                     NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens
# 10                    NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens
# ...                   ...                  ...         ...           ...
# 17600                 NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens
# 17601                 NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens
# 17602                 NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens
# 17605                 NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens
# 17614                 NaN          PRJNA612578  SARS-CoV-2  Homo Sapiens
#
#       host_disease                                       collected_by
# 0         COVID-19  Allison Smither, Gilberto Sabino-Santos, Patri...
# 2         COVID-19  SEARCH Alliance San Diego with David Pride, Ji...
# 3         COVID-19  SEARCH Alliance San Diego with David Pride, Ji...
# 9         COVID-19  Allison Smither, Gilberto Sabino-Santos, Patri...
# 10        COVID-19  SEARCH Alliance San Diego with Michael Quigley...
# ...            ...                                                ...
# 17600     COVID-19                                         EXCITE Lab
# 17601     COVID-19                                         EXCITE Lab
# 17602     COVID-19                                         EXCITE Lab
# 17605     COVID-19                                         EXCITE Lab
# 17614     COVID-19                                         EXCITE Lab
#
# [19933 rows x 14 columns]

# %%
need_to_upload_non_ww = recover_vaccine_date(need_to_upload_non_ww).drop(columns=["last_vaccinated_raw", "date_of_sars_cov_2_vaccination"])
need_to_upload_non_ww
# Out:
# /Users/karthikramesh/src/bjorn/notebooks/../src/ncbi_upload.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   needs_to_be_vaccine_timestamped["date_of_sars_cov_2_vaccination"], needs_to_be_vaccine_timestamped["vaccine_received"] = _convert_str_date_to_timestamp(needs_to_be_vaccine_timestamped["last_vaccinated_raw"], needs_to_be_vaccine_timestamped["collection_date"])
# /Users/karthikramesh/src/bjorn/notebooks/../src/ncbi_upload.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   needs_to_be_vaccine_timestamped["date_of_sars_cov_2_vaccination"] = needs_to_be_vaccine_timestamped["date_of_sars_cov_2_vaccination"].dt.strftime('%Y-%m-%d')
#         sample_name collection_date                            geo_loc_name  \
# 4500    SEARCH-8927         3/31/21  North America:USA:California:San Diego
# 4501    SEARCH-8928         3/31/21  North America:USA:California:San Diego
# 4502    SEARCH-8930         3/29/21  North America:USA:California:San Diego
# 4503    SEARCH-8931         3/30/21  North America:USA:California:San Diego
# 4701    SEARCH-9191          4/6/21  North America:USA:California:San Diego
# ...             ...             ...                                     ...
# 17600  SEARCH-49984         8/11/21  North America:USA:California:San Diego
# 17601  SEARCH-49989          8/3/21  North America:USA:California:San Diego
# 17602  SEARCH-49991          8/4/21  North America:USA:California:San Diego
# 17605  SEARCH-49996          8/9/21  North America:USA:California:San Diego
# 17614  SEARCH-49988          8/3/21  North America:USA:California:San Diego
#
#        isolate isolation_source collection_method gisaid_accession  \
# 4500       NaN              NaN        Nasal swab  EPI_ISL_1794738
# 4501       NaN              NaN        Nasal swab  EPI_ISL_1794739
# 4502       NaN              NaN        Nasal swab  EPI_ISL_1794740
# 4503       NaN              NaN        Nasal swab  EPI_ISL_1794741
# 4701       NaN              NaN        Nasal swab  EPI_ISL_1794934
# ...        ...              ...               ...              ...
# 17600      NaN              NaN               NaN  EPI_ISL_3908899
# 17601      NaN              NaN               NaN  EPI_ISL_3908901
# 17602      NaN              NaN               NaN  EPI_ISL_3908902
# 17605      NaN              NaN               NaN  EPI_ISL_3908906
# 17614      NaN              NaN               NaN  EPI_ISL_3908916
#
#                       gisaid_virus_name bioproject_accession    organism  \
# 4500       hCoV-19/USA/SEARCH-8927/2021          PRJNA612578  SARS-CoV-2
# 4501       hCoV-19/USA/SEARCH-8928/2021          PRJNA612578  SARS-CoV-2
# 4502       hCoV-19/USA/SEARCH-8930/2021          PRJNA612578  SARS-CoV-2
# 4503       hCoV-19/USA/SEARCH-8931/2021          PRJNA612578  SARS-CoV-2
# 4701       hCoV-19/USA/SEARCH-9191/2021          PRJNA612578  SARS-CoV-2
# ...                                 ...                  ...         ...
# 17600  hCoV-19/USA/CA-SEARCH-49984/2021          PRJNA612578  SARS-CoV-2
# 17601  hCoV-19/USA/CA-SEARCH-49989/2021          PRJNA612578  SARS-CoV-2
# 17602  hCoV-19/USA/CA-SEARCH-49991/2021          PRJNA612578  SARS-CoV-2
# 17605  hCoV-19/USA/CA-SEARCH-49996/2021          PRJNA612578  SARS-CoV-2
# 17614  hCoV-19/USA/CA-SEARCH-49988/2021          PRJNA612578  SARS-CoV-2
#
#                host host_disease  \
# 4500   Homo Sapiens     COVID-19
# 4501   Homo Sapiens     COVID-19
# 4502   Homo Sapiens     COVID-19
# 4503   Homo Sapiens     COVID-19
# 4701   Homo Sapiens     COVID-19
# ...             ...          ...
# 17600  Homo Sapiens     COVID-19
# 17601  Homo Sapiens     COVID-19
# 17602  Homo Sapiens     COVID-19
# 17605  Homo Sapiens     COVID-19
# 17614  Homo Sapiens     COVID-19
#
#                                             collected_by vaccine_received
# 4500   SEARCH Alliance San Diego with Michael Quigley...          vaccine
# 4501   SEARCH Alliance San Diego with Michael Quigley...           Pfizer
# 4502   SEARCH Alliance San Diego with Michael Quigley...           Pfizer
# 4503   SEARCH Alliance San Diego with Michael Quigley...           Pfizer
# 4701   SEARCH Alliance San Diego with Michael Quigley...          Moderna
# ...                                                  ...              ...
# 17600                                         EXCITE Lab              NaN
# 17601                                         EXCITE Lab              NaN
# 17602                                         EXCITE Lab              NaN
# 17605                                         EXCITE Lab              NaN
# 17614                                         EXCITE Lab              NaN
#
# [19933 rows x 14 columns]

# %%
# final cleanup
final_file = need_to_upload_non_ww.fillna("").drop_duplicates(subset=["sample_name"])
final_file.to_csv("../data/ncbi_upload/non_ww_upload_ready.csv", index=False)
final_file
# Out:
#         sample_name collection_date                            geo_loc_name  \
# 4500    SEARCH-8927         3/31/21  North America:USA:California:San Diego
# 4501    SEARCH-8928         3/31/21  North America:USA:California:San Diego
# 4502    SEARCH-8930         3/29/21  North America:USA:California:San Diego
# 4503    SEARCH-8931         3/30/21  North America:USA:California:San Diego
# 4701    SEARCH-9191          4/6/21  North America:USA:California:San Diego
# ...             ...             ...                                     ...
# 17600  SEARCH-49984         8/11/21  North America:USA:California:San Diego
# 17601  SEARCH-49989          8/3/21  North America:USA:California:San Diego
# 17602  SEARCH-49991          8/4/21  North America:USA:California:San Diego
# 17605  SEARCH-49996          8/9/21  North America:USA:California:San Diego
# 17614  SEARCH-49988          8/3/21  North America:USA:California:San Diego
#
#       isolate isolation_source collection_method gisaid_accession  \
# 4500                                  Nasal swab  EPI_ISL_1794738
# 4501                                  Nasal swab  EPI_ISL_1794739
# 4502                                  Nasal swab  EPI_ISL_1794740
# 4503                                  Nasal swab  EPI_ISL_1794741
# 4701                                  Nasal swab  EPI_ISL_1794934
# ...       ...              ...               ...              ...
# 17600                                             EPI_ISL_3908899
# 17601                                             EPI_ISL_3908901
# 17602                                             EPI_ISL_3908902
# 17605                                             EPI_ISL_3908906
# 17614                                             EPI_ISL_3908916
#
#                       gisaid_virus_name bioproject_accession    organism  \
# 4500       hCoV-19/USA/SEARCH-8927/2021          PRJNA612578  SARS-CoV-2
# 4501       hCoV-19/USA/SEARCH-8928/2021          PRJNA612578  SARS-CoV-2
# 4502       hCoV-19/USA/SEARCH-8930/2021          PRJNA612578  SARS-CoV-2
# 4503       hCoV-19/USA/SEARCH-8931/2021          PRJNA612578  SARS-CoV-2
# 4701       hCoV-19/USA/SEARCH-9191/2021          PRJNA612578  SARS-CoV-2
# ...                                 ...                  ...         ...
# 17600  hCoV-19/USA/CA-SEARCH-49984/2021          PRJNA612578  SARS-CoV-2
# 17601  hCoV-19/USA/CA-SEARCH-49989/2021          PRJNA612578  SARS-CoV-2
# 17602  hCoV-19/USA/CA-SEARCH-49991/2021          PRJNA612578  SARS-CoV-2
# 17605  hCoV-19/USA/CA-SEARCH-49996/2021          PRJNA612578  SARS-CoV-2
# 17614  hCoV-19/USA/CA-SEARCH-49988/2021          PRJNA612578  SARS-CoV-2
#
#                host host_disease  \
# 4500   Homo Sapiens     COVID-19
# 4501   Homo Sapiens     COVID-19
# 4502   Homo Sapiens     COVID-19
# 4503   Homo Sapiens     COVID-19
# 4701   Homo Sapiens     COVID-19
# ...             ...          ...
# 17600  Homo Sapiens     COVID-19
# 17601  Homo Sapiens     COVID-19
# 17602  Homo Sapiens     COVID-19
# 17605  Homo Sapiens     COVID-19
# 17614  Homo Sapiens     COVID-19
#
#                                             collected_by vaccine_received
# 4500   SEARCH Alliance San Diego with Michael Quigley...          vaccine
# 4501   SEARCH Alliance San Diego with Michael Quigley...           Pfizer
# 4502   SEARCH Alliance San Diego with Michael Quigley...           Pfizer
# 4503   SEARCH Alliance San Diego with Michael Quigley...           Pfizer
# 4701   SEARCH Alliance San Diego with Michael Quigley...          Moderna
# ...                                                  ...              ...
# 17600                                         EXCITE Lab
# 17601                                         EXCITE Lab
# 17602                                         EXCITE Lab
# 17605                                         EXCITE Lab
# 17614                                         EXCITE Lab
#
# [19927 rows x 14 columns]
